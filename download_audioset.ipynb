# %%
# using https://github.com/aoifemcdonagh/audioset-processing.git
import ffmpeg

# %%
#!git clone https://github.com/aoifemcdonagh/audioset-processing.git

# %%
# %cd ./audioset-processing
# Out:
# /Users/amywang/Documents/Cornell/F21Studio/AUTOTUNE/audioset-processing

# %%
#!pip install -r requirements.txt

# %% [markdown]
# # Classes:
# Screaming
# Whispering
# music
# Water
# Wind
# Vehicle
# Tools
# Subway, metro, underground
# alarm
# silence

# %%
# !python3 process.py download -c "screaming"
# Out:
# ...
# ./output/screaming.csv
# Label ID for "screaming": ['/m/03qc9zr']
# Finished writing CSV file for screaming
# dst_dir: ./output/screaming
# dst_dir: ./output/screaming
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=-20uudT97E0) -ar 16000 -- "./output/screaming/-20uudT97E0_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
# !python3 process.py download -c "whispering"
# Out:
# ...
# ./output/whispering.csv
# Label ID for "whispering": ['/m/02rtxlg']
# Finished writing CSV file for whispering
# dst_dir: ./output/whispering
# dst_dir: ./output/whispering
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=--PVtGGYpKY) -ar 16000 -- "./output/whispering/--PVtGGYpKY_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "water"
# Out:
# ...
# ./output/water.csv
# Multiple labels found for water
# ['/m/0838f', '/m/0j2kx', '/m/019jd', '/m/02jz0l']
# Finished writing CSV file for water
# dst_dir: ./output/water
# dst_dir: ./output/water
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=---fcVQUf3E) -ar 16000 -- "./output/water/---fcVQUf3E_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "wind"
# Out:
# ...
# ./output/wind.csv
# Multiple labels found for wind
# ['/m/085jw', '/m/026fgl', '/m/03m9d0z', '/t/dd00092', '/m/04gxbd']
# Finished writing CSV file for wind
# dst_dir: ./output/wind
# dst_dir: ./output/wind
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=--2u0ZyO3x0) -ar 16000 -- "./output/wind/--2u0ZyO3x0_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "vehicle"
# Out:
# ...
# ./output/vehicle.csv
# Multiple labels found for vehicle
# ['/m/07yv9', '/m/019jd', '/m/012f08', '/m/0912c9', '/m/03j1ly']
# Finished writing CSV file for vehicle
# dst_dir: ./output/vehicle
# dst_dir: ./output/vehicle
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=---fcVQUf3E) -ar 16000 -- "./output/vehicle/---fcVQUf3E_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "tools"
# Out:
# ...
# ./output/tools.csv
# Label ID for "tools": ['/m/07k1x']
# Finished writing CSV file for tools
# dst_dir: ./output/tools
# dst_dir: ./output/tools
# ffmpeg -ss 400 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=--STuLJ8vL0) -ar 16000 -- "./output/tools/--STuLJ8vL0_400.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "Subway, metro, underground"
# Out:
# ...
# ./output/Subway, metro, underground.csv
# Label ID for "Subway, metro, underground": ['/m/0195fx']
# Finished writing CSV file for Subway, metro, underground
# dst_dir: ./output/Subway, metro, underground
# dst_dir: ./output/Subway, metro, underground
# ffmpeg -ss 260 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=-4N3GjgnIQ0) -ar 16000 -- "./output/Subway, metro, underground/-4N3GjgnIQ0_260.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "alarm"
# Out:
# ...
# ./output/alarm.csv
# Multiple labels found for alarm
# ['/m/02mfyn', '/m/07pp_mv', '/m/046dlr', '/m/01y3hg', '/m/0c3f7m']
# Finished writing CSV file for alarm
# dst_dir: ./output/alarm
# dst_dir: ./output/alarm
# ffmpeg -ss 9 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=--OMDPXfO6o) -ar 16000 -- "./output/alarm/--OMDPXfO6o_9.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "silence"
# Out:
# ...
# ./output/silence.csv
# Label ID for "silence": ['/m/028v0c']
# Finished writing CSV file for silence
# dst_dir: ./output/silence
# dst_dir: ./output/silence
# ffmpeg -ss 0 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=-0EWw7ZGgZw) -ar 16000 -- "./output/silence/-0EWw7ZGgZw_0.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...

# %%
! yes | python3 process.py download -c "music"
# Out:
# ...
# ./output/music.csv
# Multiple labels found for music
# ['/m/04rlf', '/m/04szw', '/m/05148p4', '/m/064t9', '/m/0glt670', '/m/06by7', '/m/0gywn', '/m/015y_n', '/m/02w4v', '/m/06j64v', '/m/0ggq0m', '/m/02lkt', '/m/03mb9', '/m/08cyft', '/m/0fd3y', '/m/07lnk', '/m/0g293', '/m/0ln16', '/m/05fw6t', '/m/02v2lh', '/m/0y4f8', '/m/0164x2', '/m/02mscn', '/m/016cjb', '/m/028sqc', '/m/015vgc', '/m/0dq0md', '/m/02p0sh1', '/m/05rwpb', '/m/025td0t', '/m/02cjck', '/m/03r5q_', '/m/0l14gg', '/m/01z7dr', '/m/0140xf', '/m/0ggx5q', '/m/04wptg', '/t/dd00031', '/t/dd00032', '/t/dd00033', '/t/dd00034', '/t/dd00035', '/t/dd00036', '/t/dd00037']
# Finished writing CSV file for music
# dst_dir: ./output/music
# dst_dir: ./output/music
# ffmpeg -ss 30 -t 10 -i $(youtube-dl -f 'bestaudio' -g https://www.youtube.com/watch?v=---B_v8ZoBY) -ar 16000 -- "./output/music/---B_v8ZoBY_30.wav"
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
# ...
